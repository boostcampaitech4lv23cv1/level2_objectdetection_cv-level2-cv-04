# %%
# 모듈 import

from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)
from mmdet.utils import get_device
# Out:
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/__init__.py:21: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   'On January 1, 2023, MMCV will release v2.0.0, in which it will remove '

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/_khh_custom_configs/config1_faster_rcnn.py')

root='../../dataset/'

# dataset config 수정
cfg.data.train.classes = classes
cfg.data.train.img_prefix = root
cfg.data.train.ann_file = root + 'train.json' # train json 정보
cfg.data.train.pipeline[2]['img_scale'] = (512,512) # Resize

cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json' # test json 정보
cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize

cfg.data.samples_per_gpu = 4

## 1lv config 수정

cfg.seed = 2022
cfg.gpu_ids = [0]
cfg.work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'

cfg.model.roi_head.bbox_head.num_classes = 10

cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.checkpoint_config = dict(max_keep_ckpts=3, interval=1)
cfg.device = get_device()

# %%
# build_dataset
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!

# %%
# dataset 확인
datasets[0]
# Out:
# CocoDataset Train dataset with number of images 4883, and instance counts:
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | category          | count | category      | count | category        | count | category    | count | category     | count |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+
# | 0 [General trash] | 3965  | 1 [Paper]     | 6352  | 2 [Paper pack]  | 897   | 3 [Metal]   | 936   | 4 [Glass]    | 982   |
# | 5 [Plastic]       | 2943  | 6 [Styrofoam] | 1263  | 7 [Plastic bag] | 5178  | 8 [Battery] | 159   | 9 [Clothing] | 468   |
# +-------------------+-------+---------------+-------+-----------------+-------+-------------+-------+--------------+-------+

# %%
# 모델 build 및 pretrained network 불러오기
model = build_detector(cfg.model)
model.init_weights()
# Out:
# 2022-11-20 04:04:22,495 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2022-11-20 04:04:22,496 - mmcv - INFO - load model from: torchvision://resnet50
# 2022-11-20 04:04:22,497 - mmcv - INFO - load checkpoint from torchvision path: torchvision://resnet50
# 2022-11-20 04:04:22,712 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 2022-11-20 04:04:22,737 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2022-11-20 04:04:22,764 - mmcv - INFO - initialize RPNHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
# 2022-11-20 04:04:22,773 - mmcv - INFO - initialize Shared2FCBBoxHead with init_cfg [{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
# 2022-11-20 04:04:22,879 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,880 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,880 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,881 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,881 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,882 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,882 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,883 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,883 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,884 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,884 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,884 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,886 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,886 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,887 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,887 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,888 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,888 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,889 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,889 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,889 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,890 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,890 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,891 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,893 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,894 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,894 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,895 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,895 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,895 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,896 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,896 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,897 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,898 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,899 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,899 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,900 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,900 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,901 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,901 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,902 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,902 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,903 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,904 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,904 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,905 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,906 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,906 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,907 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,908 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,909 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,909 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,910 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,911 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,911 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,912 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,913 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,913 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,914 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,915 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,915 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,916 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,917 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,917 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,918 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,919 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,920 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,921 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,921 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,922 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,923 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,924 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,924 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,925 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,926 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,926 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,927 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,928 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,928 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,929 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,930 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,931 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,931 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,932 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,933 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,933 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,934 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,935 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,936 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,936 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,937 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,938 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,938 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,939 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,940 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,941 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,941 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,942 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,943 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,944 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,944 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,945 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,946 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,946 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,947 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,948 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,948 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,949 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,950 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,951 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,952 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,952 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,953 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,954 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,955 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,955 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,956 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,958 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,959 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,960 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,960 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,961 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,962 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,962 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,963 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,964 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,966 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,967 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,967 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,968 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,969 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,970 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,970 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,971 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,972 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,973 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,973 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,974 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,975 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,975 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,976 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,977 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,977 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,978 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,979 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,980 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,980 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,981 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,982 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,983 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,984 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,984 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,985 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,986 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,986 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,987 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,988 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,988 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,989 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2022-11-20 04:04:22,990 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 256, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:22,991 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:22,991 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:22,992 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:22,993 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:22,993 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:22,994 - mmcv - INFO -
# neck.lateral_convs.3.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:22,998 - mmcv - INFO -
# neck.lateral_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:23,001 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,002 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:23,003 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,003 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:23,004 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,005 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:23,005 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,006 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of FasterRCNN
#
# 2022-11-20 04:04:23,007 - mmcv - INFO -
# rpn_head.rpn_conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,008 - mmcv - INFO -
# rpn_head.rpn_conv.bias - torch.Size([256]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,009 - mmcv - INFO -
# rpn_head.rpn_cls.weight - torch.Size([3, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,009 - mmcv - INFO -
# rpn_head.rpn_cls.bias - torch.Size([3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,010 - mmcv - INFO -
# rpn_head.rpn_reg.weight - torch.Size([12, 256, 1, 1]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,011 - mmcv - INFO -
# rpn_head.rpn_reg.bias - torch.Size([12]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,012 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.weight - torch.Size([11, 1024]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,012 - mmcv - INFO -
# roi_head.bbox_head.fc_cls.bias - torch.Size([11]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2022-11-20 04:04:23,013 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.weight - torch.Size([40, 1024]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-11-20 04:04:23,014 - mmcv - INFO -
# roi_head.bbox_head.fc_reg.bias - torch.Size([40]):
# NormalInit: mean=0, std=0.001, bias=0
#
# 2022-11-20 04:04:23,014 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.weight - torch.Size([1024, 12544]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,015 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.0.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,016 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.weight - torch.Size([1024, 1024]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2022-11-20 04:04:23,017 - mmcv - INFO -
# roi_head.bbox_head.shared_fcs.1.bias - torch.Size([1024]):
# XavierInit: gain=1, distribution=uniform, bias=0

# %%
# 모델 학습
train_detector(model, datasets[0], cfg, distributed=False, validate=False)
# Out:
# 2022-11-20 04:04:28,581 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2022-11-20 04:04:28,586 - mmdet - INFO - Start running, host: root@f63dd08cccbb, work_dir: /opt/level2_objectdetection_cv-level2-cv-04/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash
# 2022-11-20 04:04:28,587 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-11-20 04:04:28,587 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2022-11-20 04:04:28,588 - mmdet - INFO - Checkpoints will be saved to /opt/level2_objectdetection_cv-level2-cv-04/baseline/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash by HardDiskBackend.
# 2022-11-20 04:04:43,657 - mmdet - INFO - Epoch [1][50/1221]	lr: 1.978e-03, eta: 1:13:19, time: 0.301, data_time: 0.053, memory: 2105, loss_rpn_cls: 0.4157, loss_rpn_bbox: 0.0454, loss_cls: 0.6240, acc: 87.7930, loss_bbox: 0.0856, loss: 1.1706, grad_norm: 6.8616
# 2022-11-20 04:04:55,693 - mmdet - INFO - Epoch [1][100/1221]	lr: 3.976e-03, eta: 1:05:43, time: 0.241, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1579, loss_rpn_bbox: 0.0488, loss_cls: 0.3210, acc: 94.0039, loss_bbox: 0.2236, loss: 0.7513, grad_norm: 2.6357
# 2022-11-20 04:05:07,314 - mmdet - INFO - Epoch [1][150/1221]	lr: 5.974e-03, eta: 1:02:23, time: 0.232, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1568, loss_rpn_bbox: 0.0559, loss_cls: 0.3848, acc: 92.2148, loss_bbox: 0.2974, loss: 0.8950, grad_norm: 2.7111
# 2022-11-20 04:05:20,170 - mmdet - INFO - Epoch [1][200/1221]	lr: 7.972e-03, eta: 1:02:06, time: 0.257, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1240, loss_rpn_bbox: 0.0423, loss_cls: 0.3207, acc: 93.4775, loss_bbox: 0.2498, loss: 0.7368, grad_norm: 2.3606
# 2022-11-20 04:05:32,737 - mmdet - INFO - Epoch [1][250/1221]	lr: 9.970e-03, eta: 1:01:35, time: 0.251, data_time: 0.008, memory: 2106, loss_rpn_cls: 0.1285, loss_rpn_bbox: 0.0528, loss_cls: 0.3653, acc: 92.1748, loss_bbox: 0.3002, loss: 0.8469, grad_norm: 2.5768
# 2022-11-20 04:05:44,873 - mmdet - INFO - Epoch [1][300/1221]	lr: 1.197e-02, eta: 1:00:49, time: 0.243, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1077, loss_rpn_bbox: 0.0473, loss_cls: 0.3370, acc: 92.5791, loss_bbox: 0.2789, loss: 0.7709, grad_norm: 2.4635
# 2022-11-20 04:05:56,103 - mmdet - INFO - Epoch [1][350/1221]	lr: 1.397e-02, eta: 0:59:35, time: 0.225, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1112, loss_rpn_bbox: 0.0511, loss_cls: 0.3784, acc: 91.6113, loss_bbox: 0.3085, loss: 0.8491, grad_norm: 2.6892
# 2022-11-20 04:06:07,947 - mmdet - INFO - Epoch [1][400/1221]	lr: 1.596e-02, eta: 0:58:59, time: 0.237, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1125, loss_rpn_bbox: 0.0436, loss_cls: 0.3645, acc: 92.7646, loss_bbox: 0.2532, loss: 0.7739, grad_norm: 2.4949
# 2022-11-20 04:06:19,309 - mmdet - INFO - Epoch [1][450/1221]	lr: 1.796e-02, eta: 0:58:14, time: 0.227, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1229, loss_rpn_bbox: 0.0514, loss_cls: 0.3925, acc: 91.4014, loss_bbox: 0.2929, loss: 0.8598, grad_norm: 2.6966
# 2022-11-20 04:06:30,838 - mmdet - INFO - Epoch [1][500/1221]	lr: 1.996e-02, eta: 0:57:39, time: 0.231, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1351, loss_rpn_bbox: 0.0510, loss_cls: 0.3635, acc: 92.5439, loss_bbox: 0.2524, loss: 0.8020, grad_norm: 2.5048
# 2022-11-20 04:06:42,380 - mmdet - INFO - Epoch [1][550/1221]	lr: 2.000e-02, eta: 0:57:10, time: 0.231, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0996, loss_rpn_bbox: 0.0456, loss_cls: 0.3397, acc: 92.4375, loss_bbox: 0.2541, loss: 0.7390, grad_norm: 1.9872
# 2022-11-20 04:06:54,229 - mmdet - INFO - Epoch [1][600/1221]	lr: 2.000e-02, eta: 0:56:50, time: 0.237, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0977, loss_rpn_bbox: 0.0400, loss_cls: 0.3348, acc: 92.3467, loss_bbox: 0.2539, loss: 0.7264, grad_norm: 1.9603
# 2022-11-20 04:07:06,250 - mmdet - INFO - Epoch [1][650/1221]	lr: 2.000e-02, eta: 0:56:36, time: 0.240, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1173, loss_rpn_bbox: 0.0490, loss_cls: 0.3786, acc: 91.5693, loss_bbox: 0.2735, loss: 0.8184, grad_norm: 2.2324
# 2022-11-20 04:07:18,030 - mmdet - INFO - Epoch [1][700/1221]	lr: 2.000e-02, eta: 0:56:17, time: 0.236, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1096, loss_rpn_bbox: 0.0505, loss_cls: 0.3616, acc: 91.4980, loss_bbox: 0.2681, loss: 0.7898, grad_norm: 2.0556
# 2022-11-20 04:07:29,707 - mmdet - INFO - Epoch [1][750/1221]	lr: 2.000e-02, eta: 0:55:57, time: 0.234, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0764, loss_rpn_bbox: 0.0365, loss_cls: 0.3135, acc: 92.7393, loss_bbox: 0.2224, loss: 0.6488, grad_norm: 1.7908
# 2022-11-20 04:07:41,677 - mmdet - INFO - Epoch [1][800/1221]	lr: 2.000e-02, eta: 0:55:43, time: 0.239, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0777, loss_rpn_bbox: 0.0424, loss_cls: 0.3139, acc: 92.3643, loss_bbox: 0.2342, loss: 0.6681, grad_norm: 1.7422
# 2022-11-20 04:07:54,168 - mmdet - INFO - Epoch [1][850/1221]	lr: 2.000e-02, eta: 0:55:37, time: 0.250, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1202, loss_rpn_bbox: 0.0540, loss_cls: 0.3761, acc: 91.2646, loss_bbox: 0.2677, loss: 0.8180, grad_norm: 2.0884
# 2022-11-20 04:08:06,185 - mmdet - INFO - Epoch [1][900/1221]	lr: 2.000e-02, eta: 0:55:24, time: 0.240, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1078, loss_rpn_bbox: 0.0475, loss_cls: 0.3480, acc: 91.8760, loss_bbox: 0.2505, loss: 0.7537, grad_norm: 1.7257
# 2022-11-20 04:08:18,195 - mmdet - INFO - Epoch [1][950/1221]	lr: 2.000e-02, eta: 0:55:11, time: 0.240, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.1103, loss_rpn_bbox: 0.0566, loss_cls: 0.3621, acc: 90.8564, loss_bbox: 0.2745, loss: 0.8035, grad_norm: 1.9970
# 2022-11-20 04:08:30,023 - mmdet - INFO - Epoch [1][1000/1221]	lr: 2.000e-02, eta: 0:54:55, time: 0.237, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.1032, loss_rpn_bbox: 0.0490, loss_cls: 0.3703, acc: 90.8604, loss_bbox: 0.2727, loss: 0.7952, grad_norm: 1.9228
# 2022-11-20 04:08:41,523 - mmdet - INFO - Epoch [1][1050/1221]	lr: 2.000e-02, eta: 0:54:36, time: 0.230, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0904, loss_rpn_bbox: 0.0399, loss_cls: 0.3403, acc: 91.6504, loss_bbox: 0.2428, loss: 0.7133, grad_norm: 1.8592
# 2022-11-20 04:08:52,875 - mmdet - INFO - Epoch [1][1100/1221]	lr: 2.000e-02, eta: 0:54:15, time: 0.227, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0807, loss_rpn_bbox: 0.0385, loss_cls: 0.3356, acc: 91.8057, loss_bbox: 0.2367, loss: 0.6915, grad_norm: 1.6324
# 2022-11-20 04:09:04,010 - mmdet - INFO - Epoch [1][1150/1221]	lr: 2.000e-02, eta: 0:53:53, time: 0.223, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0894, loss_rpn_bbox: 0.0476, loss_cls: 0.3357, acc: 91.9717, loss_bbox: 0.2326, loss: 0.7053, grad_norm: 1.8782
# 2022-11-20 04:09:15,551 - mmdet - INFO - Epoch [1][1200/1221]	lr: 2.000e-02, eta: 0:53:36, time: 0.231, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0806, loss_rpn_bbox: 0.0441, loss_cls: 0.3294, acc: 91.6865, loss_bbox: 0.2426, loss: 0.6967, grad_norm: 1.7472
# 2022-11-20 04:09:20,444 - mmdet - INFO - Saving checkpoint at 1 epochs
# 2022-11-20 04:09:35,081 - mmdet - INFO - Epoch [2][50/1221]	lr: 2.000e-02, eta: 0:52:44, time: 0.273, data_time: 0.051, memory: 2106, loss_rpn_cls: 0.0902, loss_rpn_bbox: 0.0458, loss_cls: 0.3472, acc: 91.5635, loss_bbox: 0.2428, loss: 0.7260, grad_norm: 1.8657
# 2022-11-20 04:09:47,142 - mmdet - INFO - Epoch [2][100/1221]	lr: 2.000e-02, eta: 0:52:35, time: 0.241, data_time: 0.008, memory: 2106, loss_rpn_cls: 0.0772, loss_rpn_bbox: 0.0457, loss_cls: 0.3350, acc: 91.0625, loss_bbox: 0.2527, loss: 0.7105, grad_norm: 1.7217
# 2022-11-20 04:09:59,147 - mmdet - INFO - Epoch [2][150/1221]	lr: 2.000e-02, eta: 0:52:25, time: 0.240, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0700, loss_rpn_bbox: 0.0395, loss_cls: 0.3367, acc: 91.0742, loss_bbox: 0.2455, loss: 0.6918, grad_norm: 1.7736
# 2022-11-20 04:10:11,105 - mmdet - INFO - Epoch [2][200/1221]	lr: 2.000e-02, eta: 0:52:14, time: 0.239, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0794, loss_rpn_bbox: 0.0391, loss_cls: 0.3109, acc: 91.8516, loss_bbox: 0.2259, loss: 0.6553, grad_norm: 1.7557
# 2022-11-20 04:10:23,323 - mmdet - INFO - Epoch [2][250/1221]	lr: 2.000e-02, eta: 0:52:05, time: 0.244, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0792, loss_rpn_bbox: 0.0491, loss_cls: 0.3206, acc: 91.5811, loss_bbox: 0.2513, loss: 0.7001, grad_norm: 1.8125
# 2022-11-20 04:10:35,497 - mmdet - INFO - Epoch [2][300/1221]	lr: 2.000e-02, eta: 0:51:56, time: 0.243, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0648, loss_rpn_bbox: 0.0353, loss_cls: 0.3096, acc: 92.2305, loss_bbox: 0.2203, loss: 0.6300, grad_norm: 1.7186
# 2022-11-20 04:10:47,595 - mmdet - INFO - Epoch [2][350/1221]	lr: 2.000e-02, eta: 0:51:46, time: 0.242, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0678, loss_rpn_bbox: 0.0356, loss_cls: 0.3101, acc: 91.7100, loss_bbox: 0.2386, loss: 0.6521, grad_norm: 1.7549
# 2022-11-20 04:10:59,287 - mmdet - INFO - Epoch [2][400/1221]	lr: 2.000e-02, eta: 0:51:33, time: 0.234, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0773, loss_rpn_bbox: 0.0399, loss_cls: 0.3020, acc: 91.9961, loss_bbox: 0.2321, loss: 0.6513, grad_norm: 1.7453
# 2022-11-20 04:11:11,136 - mmdet - INFO - Epoch [2][450/1221]	lr: 2.000e-02, eta: 0:51:21, time: 0.237, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0757, loss_rpn_bbox: 0.0443, loss_cls: 0.3322, acc: 91.1797, loss_bbox: 0.2554, loss: 0.7077, grad_norm: 1.7728
# 2022-11-20 04:11:22,857 - mmdet - INFO - Epoch [2][500/1221]	lr: 2.000e-02, eta: 0:51:08, time: 0.234, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0758, loss_rpn_bbox: 0.0388, loss_cls: 0.3325, acc: 91.2197, loss_bbox: 0.2469, loss: 0.6940, grad_norm: 1.9069
# 2022-11-20 04:11:35,302 - mmdet - INFO - Epoch [2][550/1221]	lr: 2.000e-02, eta: 0:51:00, time: 0.249, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0727, loss_rpn_bbox: 0.0426, loss_cls: 0.3320, acc: 91.2930, loss_bbox: 0.2407, loss: 0.6881, grad_norm: 1.7456
# 2022-11-20 04:11:47,103 - mmdet - INFO - Epoch [2][600/1221]	lr: 2.000e-02, eta: 0:50:48, time: 0.236, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0607, loss_rpn_bbox: 0.0344, loss_cls: 0.3086, acc: 92.0596, loss_bbox: 0.2243, loss: 0.6279, grad_norm: 1.6774
# 2022-11-20 04:11:59,379 - mmdet - INFO - Epoch [2][650/1221]	lr: 2.000e-02, eta: 0:50:39, time: 0.246, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0764, loss_rpn_bbox: 0.0385, loss_cls: 0.3127, acc: 92.1309, loss_bbox: 0.2251, loss: 0.6527, grad_norm: 1.8538
# 2022-11-20 04:12:10,791 - mmdet - INFO - Epoch [2][700/1221]	lr: 2.000e-02, eta: 0:50:24, time: 0.228, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0742, loss_rpn_bbox: 0.0391, loss_cls: 0.3230, acc: 91.0918, loss_bbox: 0.2571, loss: 0.6934, grad_norm: 1.7333
# 2022-11-20 04:12:22,587 - mmdet - INFO - Epoch [2][750/1221]	lr: 2.000e-02, eta: 0:50:11, time: 0.236, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0626, loss_rpn_bbox: 0.0359, loss_cls: 0.3229, acc: 91.5234, loss_bbox: 0.2328, loss: 0.6542, grad_norm: 1.6783
# 2022-11-20 04:12:34,514 - mmdet - INFO - Epoch [2][800/1221]	lr: 2.000e-02, eta: 0:50:00, time: 0.239, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0751, loss_rpn_bbox: 0.0421, loss_cls: 0.3622, acc: 90.3428, loss_bbox: 0.2720, loss: 0.7514, grad_norm: 1.7923
# 2022-11-20 04:12:46,702 - mmdet - INFO - Epoch [2][850/1221]	lr: 2.000e-02, eta: 0:49:50, time: 0.244, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0760, loss_rpn_bbox: 0.0446, loss_cls: 0.3285, acc: 91.4668, loss_bbox: 0.2446, loss: 0.6938, grad_norm: 1.8745
# 2022-11-20 04:12:59,170 - mmdet - INFO - Epoch [2][900/1221]	lr: 2.000e-02, eta: 0:49:41, time: 0.249, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0577, loss_rpn_bbox: 0.0346, loss_cls: 0.3261, acc: 91.3887, loss_bbox: 0.2333, loss: 0.6517, grad_norm: 1.7423
# 2022-11-20 04:13:11,113 - mmdet - INFO - Epoch [2][950/1221]	lr: 2.000e-02, eta: 0:49:30, time: 0.239, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0579, loss_rpn_bbox: 0.0379, loss_cls: 0.3366, acc: 90.8340, loss_bbox: 0.2590, loss: 0.6915, grad_norm: 1.7264
# 2022-11-20 04:13:22,732 - mmdet - INFO - Epoch [2][1000/1221]	lr: 2.000e-02, eta: 0:49:16, time: 0.232, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0616, loss_rpn_bbox: 0.0386, loss_cls: 0.3201, acc: 91.6309, loss_bbox: 0.2219, loss: 0.6421, grad_norm: 1.7415
# 2022-11-20 04:13:34,360 - mmdet - INFO - Epoch [2][1050/1221]	lr: 2.000e-02, eta: 0:49:03, time: 0.233, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0629, loss_rpn_bbox: 0.0404, loss_cls: 0.3078, acc: 91.5684, loss_bbox: 0.2317, loss: 0.6429, grad_norm: 1.8070
# 2022-11-20 04:13:46,479 - mmdet - INFO - Epoch [2][1100/1221]	lr: 2.000e-02, eta: 0:48:52, time: 0.242, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0777, loss_rpn_bbox: 0.0496, loss_cls: 0.3430, acc: 90.8242, loss_bbox: 0.2577, loss: 0.7280, grad_norm: 1.8692
# 2022-11-20 04:13:58,876 - mmdet - INFO - Epoch [2][1150/1221]	lr: 2.000e-02, eta: 0:48:43, time: 0.248, data_time: 0.009, memory: 2106, loss_rpn_cls: 0.0721, loss_rpn_bbox: 0.0423, loss_cls: 0.3442, acc: 90.7051, loss_bbox: 0.2733, loss: 0.7319, grad_norm: 1.8606
# 2022-11-20 04:14:11,190 - mmdet - INFO - Epoch [2][1200/1221]	lr: 2.000e-02, eta: 0:48:33, time: 0.246, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0768, loss_rpn_bbox: 0.0404, loss_cls: 0.3015, acc: 91.9307, loss_bbox: 0.2184, loss: 0.6371, grad_norm: 1.7485
# 2022-11-20 04:14:16,138 - mmdet - INFO - Saving checkpoint at 2 epochs
# 2022-11-20 04:14:30,984 - mmdet - INFO - Epoch [3][50/1221]	lr: 2.000e-02, eta: 0:48:02, time: 0.279, data_time: 0.050, memory: 2106, loss_rpn_cls: 0.0579, loss_rpn_bbox: 0.0383, loss_cls: 0.2960, acc: 92.0303, loss_bbox: 0.2246, loss: 0.6169, grad_norm: 1.7271
# 2022-11-20 04:14:42,183 - mmdet - INFO - Epoch [3][100/1221]	lr: 2.000e-02, eta: 0:47:47, time: 0.224, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0588, loss_rpn_bbox: 0.0338, loss_cls: 0.2710, acc: 92.5898, loss_bbox: 0.1950, loss: 0.5586, grad_norm: 1.6211
# 2022-11-20 04:14:53,930 - mmdet - INFO - Epoch [3][150/1221]	lr: 2.000e-02, eta: 0:47:34, time: 0.235, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0563, loss_rpn_bbox: 0.0386, loss_cls: 0.3252, acc: 91.1553, loss_bbox: 0.2434, loss: 0.6635, grad_norm: 1.8683
# 2022-11-20 04:15:06,061 - mmdet - INFO - Epoch [3][200/1221]	lr: 2.000e-02, eta: 0:47:24, time: 0.243, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0604, loss_rpn_bbox: 0.0411, loss_cls: 0.3317, acc: 91.2500, loss_bbox: 0.2483, loss: 0.6816, grad_norm: 1.7805
# 2022-11-20 04:15:18,559 - mmdet - INFO - Epoch [3][250/1221]	lr: 2.000e-02, eta: 0:47:15, time: 0.250, data_time: 0.008, memory: 2106, loss_rpn_cls: 0.0561, loss_rpn_bbox: 0.0367, loss_cls: 0.3069, acc: 91.5566, loss_bbox: 0.2209, loss: 0.6206, grad_norm: 1.8295
# 2022-11-20 04:15:30,537 - mmdet - INFO - Epoch [3][300/1221]	lr: 2.000e-02, eta: 0:47:04, time: 0.240, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0530, loss_rpn_bbox: 0.0345, loss_cls: 0.3321, acc: 90.9414, loss_bbox: 0.2403, loss: 0.6600, grad_norm: 1.7574
# 2022-11-20 04:15:42,251 - mmdet - INFO - Epoch [3][350/1221]	lr: 2.000e-02, eta: 0:46:51, time: 0.234, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0569, loss_rpn_bbox: 0.0366, loss_cls: 0.3116, acc: 91.4355, loss_bbox: 0.2376, loss: 0.6427, grad_norm: 1.8132
# 2022-11-20 04:15:53,925 - mmdet - INFO - Epoch [3][400/1221]	lr: 2.000e-02, eta: 0:46:39, time: 0.233, data_time: 0.007, memory: 2106, loss_rpn_cls: 0.0614, loss_rpn_bbox: 0.0456, loss_cls: 0.3123, acc: 91.4746, loss_bbox: 0.2367, loss: 0.6560, grad_norm: 1.8481
# 2022-11-20 04:16:05,927 - mmdet - INFO - Epoch [3][450/1221]	lr: 2.000e-02, eta: 0:46:27, time: 0.240, data_time: 0.006, memory: 2106, loss_rpn_cls: 0.0581, loss_rpn_bbox: 0.0321, loss_cls: 0.3316, acc: 90.9424, loss_bbox: 0.2484, loss: 0.6702, grad_norm: 1.8720
